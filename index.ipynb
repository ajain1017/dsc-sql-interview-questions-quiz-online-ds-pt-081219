# %% [markdown]
# # SQL Interview Questions  - Quiz
#
#
# ## Introduction
#
# This quiz contains questions on topics you can expect to see in an interview pertaining to SQL and Relational Databases. Some of them are multiple choice, while some are short answer. For these short answer questions, double click on the Jupyter Notebook and type your answer below the line.
#
# ## Question 1
#
# What are the 4 main datatypes in SQLite3? Can we use other common types from other kinds of SQL?
#
# Type your answer below this line:
# The four main datatypes are TEXT, INTEGER, REAL, and BLOB. Yes, you may use other types found in other kinds of SQL as SQLite3 is a dynamic version of SQL and is backwards compatible.
#
#
#
#
# ## Question 2
#
# Explain the relationship between **Primary Keys** and **Foreign Keys**.
#
# Type your answer below this line:
# The primary key(s) of a table are those column(s) which uniquely identify a row. A foreign key is a column (or columns) that references a column (most often the primary key) of another table. A foreign key is a key used to link two tables together. A primary key-foreign key relationship defines a one-to-many relationship between two tables in the database.
#
#
#
#
#
# ## Question 3
#
# Explain the different types of relationships entities can have in a SQL database.
#
# Type your answer below this line:
# A one-to-one relationship allows only one record on each side of the relationship. The primary key relates to only one or no record in another table. A one-to-many relationship allows a single record in one table to be related to multiple records in another table. The last many-to-many relationship allows many records in a table to be linked to many records in another table.
#
#
# ## Question 4
#
# Explain the various types of JOINs possible with SQL.
#
# Type your answer below this line:
# By default, a JOIN is an Inner Join. However, all the possible joins are:
# Left Join including intersection where intersection of the two tables is nonempty
# Left Join excluding intersection
# Right Join including intersection where intersection of the two tables is nonempty
# Right Join excluding intersection
# Full Outer Join including intersection
# Outer Join excluding intersection
#
#
#
# ## Question 5
#
# Explain the relationship between Aggregate functions and GROUP BY statements.
#
# Type your answer below this line:
# The GROUP BY clause returns one row for each group and thus, for each group, you can apply an aggregate function such to provide more information about each group. If you were to use an aggregate function, you must order the data usually by using a group by statement.
#
#
#
# ## Question 6
#
# What role do Associative Entities play (JOIN Tables) in many-to-many JOINs?
#
#
# Type your answer below this line:
# Associative Entity tables are used to indicate the associations between two seperate entities.
#
#
#
# ## Summary
#
# In this lesson, we practiced answering open-ended interview questions for SQL and Relational Databases.
